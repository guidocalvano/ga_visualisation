# %% [markdown]
# Easy
# 1. e1 +e2
# 2. Because the length of e1 + e2 is not normalized
# 3. ? I think c e1 + c e12
# 4. (40 / 360) * 2 pi + e12
# 5. 7 ?
# 6. (a v b) + 2pi * 80/360

# %% [markdown]
# Medium
# 1. e3 + 4e0 , e1 + 7e0
#
# 2. A rotoreflection
#
# 3. Point reflection ?
#
# 4. A plane reflection ?
#
# 5. grade0((A/len(A))(B/len(b)))
#
# 6. ?
#
# 7. ?

# %% [markdown]
# Hard
#
# 1. Scalar part (A v B)  (i.e. create the translation from A to B, and then take the distance from the translation)
# 2. To preserve direction
# 3. ABCDE where A and B are parallel, C and D are orthogonal to both A and B, but not to each other, and E is not orthogonal to any of all these planes
